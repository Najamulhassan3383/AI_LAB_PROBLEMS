# %%
import math

class Node:
    def __init__(self, state, parent, actions, location, huristic, totalcost=0):
        self.state = state
        self.parent = parent
        self.actions = actions
        self.location = location
        self.huristic = huristic
        self.totalcost = totalcost

# Define the graph
graph = {
    "A": Node("A", None, [("F", 1)], (0, 0), 0),
    "B": Node("B", None, [("C", 1), ("G", 1)], (0, 2), 0),
    "C": Node("C", None, [("B", 1), ("D", 1)], (0, 3), 0),
    "D": Node("D", None, [("C", 1), ("E", 1)], (0, 4), 0),
    "E": Node("E", None, [("D", 1)], (0, 5), 0),
    "F": Node("F", None, [("A", 1), ("H", 1)], (1, 0), 0),
    "G": Node("G", None, [("B", 1), ("J", 1)], (1, 2), 0),
    "H": Node("H", None, [("F", 1), ("I", 1), ("M", 1)], (2, 0), 0),
    "I": Node("I", None, [("N", 1), ("J", 1)], (2, 1), 0),
    "J": Node("J", None, [("G", 1), ("I", 1)], (2, 2), 0),
    "K": Node("K", None, [("L", 1), ("P", 1)], (2, 4), 0),
    "L": Node("L", None, [("K", 1), ("Q", 1)], (2, 5), 0),
    "M": Node("M", None, [("H", 1), ("N", 1), ("R", 1)], (3, 0), 0),
    "N": Node("N", None, [("I", 1), ("M", 1), ("S", 1)], (3, 1), 0),
    "O": Node("O", None, [("P", 1), ("U", 1)], (3, 3), 0),
    "P": Node("P", None, [("Q", 1), ("O", 1)], (3, 4), 0),
    "Q": Node("Q", None, [("L", 1), ("P", 1), ("V", 1)], (3, 5), 0),
    "R": Node("R", None, [("M", 1), ("S", 1)], (4, 0), 0),
    "S": Node("S", None, [("N", 1), ("R", 1), ("T", 1)], (4, 1), 0),
    "T": Node("T", None, [("S", 1), ("U", 1), ("W", 1)], (4, 2), 0),
    "U": Node("U", None, [("O", 1), ("T", 1)], (4, 3), 0),
    "V": Node("V", None, [("Q", 1), ("Y", 1)], (4, 5), 0),
    "W": Node("W", None, [("T", 1)], (5, 2), 0),
    "X": Node("X", None, [("Y", 1)], (5, 4), 0),
    "Y": Node("Y", None, [("V", 1), ("X", 1)], (5, 5), 0),
}



# Define the start and goal nodes
start = "A"
goal = "Y"

def find_min(queue):
    min = math.inf
    node = ''
    for i in queue:
        if min > queue[i][1]:
            min = queue[i][1]
            node =  i 
    return node




# Define the action sequence function
def actionSequence(graph, start, goal):
    solution = [goal]
    parent = graph[goal].parent
    while parent != start:
        print(parent)
        solution.append(parent)
        parent  = graph[parent].parent
        
        
    solution.reverse()
    return solution

start = 'A'
goal = "Y"
final_x = graph["Y"].location[0]
final_y = graph["Y"].location[1]
def euclidean_distance(node):
    print(node.location)
    dist = math.sqrt((final_x - x)**2 + (final_y-y)**2)
    return dist


#calculte the huristic value

# %%
# graph = {'A': Node('A', None, [('B', 6), ('C',9), ('E',1)], 0),
# 'B': Node('B', None, [('A', 6), ('D',3), ('E',4)], 0),
# 'C': Node('C', None, [('A', 9), ('F',2), ('G',3)], 0),
# 'D': Node('D', None, [('B',3), ('E, 5), ('E',7)], 0),
# 'E': Node('E', None, [('A',1), ('B',4), ('D',5), ('F', 6)], 0),
# 'F': Node('F', None, [('C',2), ('E', 6), ('D',7)], 0),
# 'G': Node('G', None, [('C',3)], 0))

heuristic = {
    "Arad": 366,
    "Bucharest": 0,
    "Craiova": 160,
    "Drobeta": 242,
    "Eforie": 161,
    "Fagaras": 178,
    "Giurgiu": 77,
    "Hirsova": 151,
    "Iasi": 226,
    "Lugoj": 244,
    "Mehadia": 241,
    "Neamt": 234,
    "Oradea": 380,
    "Pitesti": 98,
    "Rimnicu Vilcea": 193,
    "Sibiu": 253,
    "Timisoara": 329,
    "Urziceni": 80,
    "Vaslui": 199,
    "Zerind": 374
    
}
romanian_map = {
    'Arad': Node('Arad', None, [('Zerind', 75), ('Sibiu', 140), ('Timisoara', 118)], 0, 0),
    'Zerind': Node('Zerind', None, [('Arad', 75), ('Oradea', 71)], 0, 0),
    'Oradea': Node('Oradea', None, [('Zerind', 71), ('Sibiu', 151)], 0, 0),
    'Sibiu': Node('Sibiu', None, [('Arad', 140), ('Oradea', 151), ('Fagaras', 99), ('Rimnicu Vilcea', 80)], 0, 0),
    'Timisoara': Node('Timisoara', None, [('Arad', 118), ('Lugoj', 111)], 0, 0),
    'Lugoj': Node('Lugoj', None, [('Timisoara', 111), ('Mehadia', 70)], 0, 0),
    'Mehadia': Node('Mehadia', None, [('Lugoj', 70), ('Drobeta', 75)], 0, 0),
    'Drobeta': Node('Drobeta', None, [('Mehadia', 75), ('Craiova', 120)], 0, 0),
    'Craiova': Node('Craiova', None, [('Drobeta', 120), ('Rimnicu Vilcea', 146), ('Pitesti', 138)], 0, 0),
    'Rimnicu Vilcea': Node('Rimnicu Vilcea', None, [('Sibiu', 80), ('Craiova', 146), ('Pitesti', 97)], 0, 0),
    'Fagaras': Node('Fagaras', None, [('Sibiu', 99), ('Bucharest', 211)], 0, 0),
    'Pitesti': Node('Pitesti', None, [('Rimnicu Vilcea', 97), ('Craiova', 138), ('Bucharest', 101)], 0, 0),
    'Bucharest': Node('Bucharest', None, [('Fagaras', 211), ('Pitesti', 101), ('Giurgiu', 90), ('Urziceni', 85)], 0, 0),
    'Giurgiu': Node('Giurgiu', None, [('Bucharest', 90)], 0, 0),
    'Urziceni': Node('Urziceni', None, [('Bucharest', 85), ('Hirsova', 98), ('Vaslui', 142)], 0, 0),
    'Hirsova': Node('Hirsova', None, [('Urziceni', 98), ('Eforie', 86)], 0, 0),
    'Eforie': Node('Eforie', None, [('Hirsova', 86)], 0, 0),
    'Vaslui': Node('Vaslui', None, [('Urziceni', 142), ('Iasi', 92)], 0, 0),
    'Iasi': Node('Iasi', None, [('Vaslui', 92), ('Neamt', 87)], 0, 0),
    'Neamt': Node('Neamt', None, [('Iasi', 87)], 0, 0)
}

# %%
def A_star(graph,start, goal):
    frontier = {start: 0}
    explored = []
    while frontier:
        node = min(frontier, key=frontier.get)
        del frontier[node]
        explored.append(node)
        if node == goal:
            return actionSequence(graph, start, goal)
        for child, cost in graph[node].actions:
            if graph[child[0]].parent == child or child[0] == start or explored[child[0]][1] <= currentCost + graph[child[0]].huristic:
                    continue
            
            if child not in explored:
                total_cost = graph[node].totalcost + cost
                if child not in frontier:
                    graph[child].totalcost = total_cost
                    graph[child].parent = node
                    frontier[child] = total_cost + graph[child].huristic
                elif total_cost + graph[child].huristic < frontier[child]:
                    graph[child].totalcost = total_cost
                    graph[child].parent = node
                    frontier[child] = total_cost + graph[child].huristic
    return False

print(A_star(romanian_map, "Arad", "Bucharest"))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /home/najam/Desktop/Ai lab/lab_prep/Astar.ipynb Cell 3 line 2
#      <a href='vscode-notebook-cell:/home/najam/Desktop/Ai%20lab/lab_prep/Astar.ipynb#W1sZmlsZQ%3D%3D?line=22'>23</a>                     frontier[child] = total_cost + graph[child].huristic
#      <a href='vscode-notebook-cell:/home/najam/Desktop/Ai%20lab/lab_prep/Astar.ipynb#W1sZmlsZQ%3D%3D?line=23'>24</a>     return False
# ---> <a href='vscode-notebook-cell:/home/najam/Desktop/Ai%20lab/lab_prep/Astar.ipynb#W1sZmlsZQ%3D%3D?line=25'>26</a> print(A_star(romanian_map, "Arad", "Bucharest"))
#
# /home/najam/Desktop/Ai lab/lab_prep/Astar.ipynb Cell 3 line 1
#       <a href='vscode-notebook-cell:/home/najam/Desktop/Ai%20lab/lab_prep/Astar.ipynb#W1sZmlsZQ%3D%3D?line=8'>9</a>     return actionSequence(graph, start, goal)
#      <a href='vscode-notebook-cell:/home/najam/Desktop/Ai%20lab/lab_prep/Astar.ipynb#W1sZmlsZQ%3D%3D?line=9'>10</a> for child, cost in graph[node].actions:
# ---> <a href='vscode-notebook-cell:/home/najam/Desktop/Ai%20lab/lab_prep/Astar.ipynb#W1sZmlsZQ%3D%3D?line=10'>11</a>     if graph[child[0]].parent == child or child[0] == start or explored[child[0]][1] <= currentCost + graph[child[0]].huristic:
#      <a href='vscode-notebook-cell:/home/najam/Desktop/Ai%20lab/lab_prep/Astar.ipynb#W1sZmlsZQ%3D%3D?line=11'>12</a>             continue
#      <a href='vscode-notebook-cell:/home/najam/Desktop/Ai%20lab/lab_prep/Astar.ipynb#W1sZmlsZQ%3D%3D?line=13'>14</a>     if child not in explored:
#
# KeyError: 'Z'
